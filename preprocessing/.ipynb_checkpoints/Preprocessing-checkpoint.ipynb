# %% [markdown]
# #imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importando dados
fifa_df = pd.read_csv('../completo.csv')
missing = fifa_df.isnull().sum()
missing
# Out:
# ID                                 0
# name                               0
# full_name                          0
# club                             253
# club_logo                        253
# special                            0
# age                                0
# league                           253
# birth_date                         0
# height_cm                          0
# weight_kg                          0
# body_type                          0
# real_face                          0
# flag                               0
# nationality                        0
# photo                              0
# eur_value                          0
# eur_wage                           0
# eur_release_clause              1494
# overall                            0
# potential                          0
# pac                                0
# sho                                0
# pas                                0
# dri                                0
# def                                0
# phy                                0
# international_reputation           0
# skill_moves                        0
# weak_foot                          0
#                                 ...
# acrobat_speciality                 0
# strength_speciality                0
# clinical_finisher_speciality       0
# prefers_rs                         0
# prefers_rw                         0
# prefers_rf                         0
# prefers_ram                        0
# prefers_rcm                        0
# prefers_rm                         0
# prefers_rdm                        0
# prefers_rcb                        0
# prefers_rb                         0
# prefers_rwb                        0
# prefers_st                         0
# prefers_lw                         0
# prefers_cf                         0
# prefers_cam                        0
# prefers_cm                         0
# prefers_lm                         0
# prefers_cdm                        0
# prefers_cb                         0
# prefers_lb                         0
# prefers_lwb                        0
# prefers_ls                         0
# prefers_lf                         0
# prefers_lam                        0
# prefers_lcm                        0
# prefers_ldm                        0
# prefers_lcb                        0
# prefers_gk                         0
# Length: 185, dtype: int64

# %%
# Tirando todos os espaços em branco antes e depois das palavras
fifa_df = fifa_df.applymap(lambda x: x.strip() if type(x) is str else x)

# %% [markdown]
# ## 2.0 Separando variáveis categóricas das variáveis numéricas

# %%
numerical_variables = ['eur_value', 'eur_wage', 'eur_release_clause','age', 'height_cm', 'weight_kg', 'ID', 'special', 'overall', 'potential', 'pac', 'sho', 'pas', 'dri', 'def', 'phy', 'international_reputation', 'skill_moves', 'weak_foot', 'crossing', 'finishing', 'heading_accuracy', 'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy', 'long_passing', 'ball_control', 'acceleration', 'sprint_speed', 'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina', 'strength',
'long_shots', 'aggression', 'interceptions', 'positioning', 'vision', 'penalties', 'composure', 'marking', 'standing_tackle', 'sliding_tackle', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning', 'gk_reflexes', 'rs', 'rw', 'rf', 'ram', 'rcm', 'rm', 'rdm', 'rcb', 'rb', 'rwb', 'st', 'lw', 'cf', 'cam', 'cm', 'lm', 'cdm', 'cb', 'lb', 'lwb', 'ls', 'lf', 'lam', 'lcm', 'ldm', 'lcb', 'gk']
categorical_variables = [v for v in fifa_df.columns if v not in numerical_variables]

# %% [markdown]
# ## 3.0 Tratando variáveis Categóricas

# %%
fifa_df[categorical_variables].astype(str).describe()
# Out:
#                name   full_name   club club_logo                 league  \
# count         17994       17994  17994     17994                  17994
# unique        17022       17891    648       648                     42
# top     J. Valencia  Ben Davies    nan       nan  Argentinian Superliga
# freq              7           3    253       253                    780
#
#         birth_date body_type real_face  \
# count        17994     17994     17994
# unique        6010         9         2
# top     1992-02-29    Normal     False
# freq           225     10587     16772
#
#                                           flag nationality    ...      \
# count                                    17994       17994    ...
# unique                                     164         164    ...
# top     https://cdn.sofifa.org/flags/14@3x.png     England    ...
# freq                                      1631        1631    ...
#
#        prefers_cb prefers_lb prefers_lwb prefers_ls prefers_lf prefers_lam  \
# count       17994      17994       17994      17994      17994       17994
# unique          2          2           2          1          1           1
# top         False      False       False      False      False       False
# freq        14354      15931       17796      17994      17994       17994
#
#        prefers_lcm prefers_ldm prefers_lcb prefers_gk
# count        17994       17994       17994      17994
# unique           1           1           1          2
# top          False       False       False      False
# freq         17994       17994       17994      15973
#
# [4 rows x 105 columns]

# %%
# Amostra do dataset
fifa_df[categorical_variables].head()
# Out:
#                 name                     full_name                 club  \
# 0  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro       Real Madrid CF
# 1           L. Messi                  Lionel Messi         FC Barcelona
# 2             Neymar    Neymar da Silva Santos Jr.  Paris Saint-Germain
# 3          L. Suárez                   Luis Suárez         FC Barcelona
# 4           M. Neuer                  Manuel Neuer     FC Bayern Munich
#
#                                  club_logo                    league  \
# 0  https://cdn.sofifa.org/18/teams/243.png  Spanish Primera División
# 1  https://cdn.sofifa.org/18/teams/241.png  Spanish Primera División
# 2   https://cdn.sofifa.org/18/teams/73.png            French Ligue 1
# 3  https://cdn.sofifa.org/18/teams/241.png  Spanish Primera División
# 4   https://cdn.sofifa.org/18/teams/21.png         German Bundesliga
#
#    birth_date   body_type  real_face                                    flag  \
# 0  1985-02-05  C. Ronaldo       True  https://cdn.sofifa.org/flags/38@3x.png
# 1  1987-06-24       Messi       True  https://cdn.sofifa.org/flags/52@3x.png
# 2  1992-02-05      Neymar       True  https://cdn.sofifa.org/flags/54@3x.png
# 3  1987-01-24      Normal       True  https://cdn.sofifa.org/flags/60@3x.png
# 4  1986-03-27      Normal       True  https://cdn.sofifa.org/flags/21@3x.png
#
#   nationality     ...     prefers_cb prefers_lb prefers_lwb prefers_ls  \
# 0    Portugal     ...          False      False       False      False
# 1   Argentina     ...          False      False       False      False
# 2      Brazil     ...          False      False       False      False
# 3     Uruguay     ...          False      False       False      False
# 4     Germany     ...          False      False       False      False
#
#    prefers_lf  prefers_lam  prefers_lcm  prefers_ldm  prefers_lcb  prefers_gk
# 0       False        False        False        False        False       False
# 1       False        False        False        False        False       False
# 2       False        False        False        False        False       False
# 3       False        False        False        False        False       False
# 4       False        False        False        False        False        True
#
# [5 rows x 105 columns]

# %%
fifa_df[categorical_variables].isnull().sum()
# Out:
# name                                0
# full_name                           0
# club                              253
# club_logo                         253
# league                            253
# birth_date                          0
# body_type                           0
# real_face                           0
# flag                                0
# nationality                         0
# photo                               0
# work_rate_att                       0
# work_rate_def                       0
# preferred_foot                      0
# 1_on_1_rush_trait                   0
# acrobatic_clearance_trait           0
# argues_with_officials_trait         0
# avoids_using_weaker_foot_trait      0
# backs_into_player_trait             0
# bicycle_kicks_trait                 0
# cautious_with_crosses_trait         0
# chip_shot_trait                     0
# chipped_penalty_trait               0
# comes_for_crosses_trait             0
# corner_specialist_trait             0
# diver_trait                         0
# dives_into_tackles_trait            0
# diving_header_trait                 0
# driven_pass_trait                   0
# early_crosser_trait                 0
#                                  ...
# acrobat_speciality                  0
# strength_speciality                 0
# clinical_finisher_speciality        0
# prefers_rs                          0
# prefers_rw                          0
# prefers_rf                          0
# prefers_ram                         0
# prefers_rcm                         0
# prefers_rm                          0
# prefers_rdm                         0
# prefers_rcb                         0
# prefers_rb                          0
# prefers_rwb                         0
# prefers_st                          0
# prefers_lw                          0
# prefers_cf                          0
# prefers_cam                         0
# prefers_cm                          0
# prefers_lm                          0
# prefers_cdm                         0
# prefers_cb                          0
# prefers_lb                          0
# prefers_lwb                         0
# prefers_ls                          0
# prefers_lf                          0
# prefers_lam                         0
# prefers_lcm                         0
# prefers_ldm                         0
# prefers_lcb                         0
# prefers_gk                          0
# Length: 105, dtype: int64

# %%
## Jogadores que não possuem Clube, Logo do Clube ou Liga. Deletar.
fifa_df = fifa_df[~fifa_df['club'].isna() & fifa_df['club_logo'].isna() & fifa_df['league'].isna()]
fifa_df[categorical_variables].isnull().sum()
# Out:
# name                              0
# full_name                         0
# club                              0
# club_logo                         0
# league                            0
# birth_date                        0
# body_type                         0
# real_face                         0
# flag                              0
# nationality                       0
# photo                             0
# work_rate_att                     0
# work_rate_def                     0
# preferred_foot                    0
# 1_on_1_rush_trait                 0
# acrobatic_clearance_trait         0
# argues_with_officials_trait       0
# avoids_using_weaker_foot_trait    0
# backs_into_player_trait           0
# bicycle_kicks_trait               0
# cautious_with_crosses_trait       0
# chip_shot_trait                   0
# chipped_penalty_trait             0
# comes_for_crosses_trait           0
# corner_specialist_trait           0
# diver_trait                       0
# dives_into_tackles_trait          0
# diving_header_trait               0
# driven_pass_trait                 0
# early_crosser_trait               0
#                                  ..
# acrobat_speciality                0
# strength_speciality               0
# clinical_finisher_speciality      0
# prefers_rs                        0
# prefers_rw                        0
# prefers_rf                        0
# prefers_ram                       0
# prefers_rcm                       0
# prefers_rm                        0
# prefers_rdm                       0
# prefers_rcb                       0
# prefers_rb                        0
# prefers_rwb                       0
# prefers_st                        0
# prefers_lw                        0
# prefers_cf                        0
# prefers_cam                       0
# prefers_cm                        0
# prefers_lm                        0
# prefers_cdm                       0
# prefers_cb                        0
# prefers_lb                        0
# prefers_lwb                       0
# prefers_ls                        0
# prefers_lf                        0
# prefers_lam                       0
# prefers_lcm                       0
# prefers_ldm                       0
# prefers_lcb                       0
# prefers_gk                        0
# Length: 105, dtype: int64

# %% [markdown]
# ## Variáveis Numéricas

# %%
fifa_df[numerical_variables].isnull().sum()
# Out:
# eur_value                   0
# eur_wage                    0
# eur_release_clause          0
# age                         0
# height_cm                   0
# weight_kg                   0
# ID                          0
# special                     0
# overall                     0
# potential                   0
# pac                         0
# sho                         0
# pas                         0
# dri                         0
# def                         0
# phy                         0
# international_reputation    0
# skill_moves                 0
# weak_foot                   0
# crossing                    0
# finishing                   0
# heading_accuracy            0
# short_passing               0
# volleys                     0
# dribbling                   0
# curve                       0
# free_kick_accuracy          0
# long_passing                0
# ball_control                0
# acceleration                0
#                            ..
# gk_kicking                  0
# gk_positioning              0
# gk_reflexes                 0
# rs                          0
# rw                          0
# rf                          0
# ram                         0
# rcm                         0
# rm                          0
# rdm                         0
# rcb                         0
# rb                          0
# rwb                         0
# st                          0
# lw                          0
# cf                          0
# cam                         0
# cm                          0
# lm                          0
# cdm                         0
# cb                          0
# lb                          0
# lwb                         0
# ls                          0
# lf                          0
# lam                         0
# lcm                         0
# ldm                         0
# lcb                         0
# gk                          0
# Length: 80, dtype: int64

# %% [markdown]
# # 4.2 Normalizando os dados

# %%
fifa_df[numerical_variables].head()

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
fifa_df[numerical_variables] = scaler.fit_transform(fifa_df[numerical_variables])
fifa_df[numerical_variables].head()
